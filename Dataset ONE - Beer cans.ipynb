# %% [markdown]
# # Homework 6, Part One: Lots and lots of questions about beer

# %% [markdown]
# ### Do your importing and your setup

# %%
import pandas as pd
type(pd.read_csv("craftcans.csv"))
df = pd.read_csv("craftcans.csv")

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV IBUs
# 0  16 oz.  4.50%   50
# 1  16 oz.  4.90%   26
# 2  16 oz.  4.80%   19
# 3  16 oz.  6.00%   38
# 4  16 oz.  6.00%   25

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer        object
# Brewery     object
# Location    object
# Style       object
# Size        object
# ABV         object
# IBUs        object
# dtype: object

# %% [markdown]
# # Checking out our alcohol

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df.sort_values(by="Brewery", ascending=False).head(10)
# Out:
#                              Beer                  Brewery    Location  \
# 1600          Wynkoop Pumpkin Ale  Wynkoop Brewing Company  Denver, CO
# 1978              B3K Black Lager  Wynkoop Brewing Company  Denver, CO
# 1308           Patty's Chile Beer  Wynkoop Brewing Company  Denver, CO
# 1336    Colorojo Imperial Red Ale  Wynkoop Brewing Company  Denver, CO
# 2332         Rail Yard Ale (2009)  Wynkoop Brewing Company  Denver, CO
# 1610  Rocky Mountain Oyster Stout  Wynkoop Brewing Company  Denver, CO
# 2286          Silverback Pale Ale  Wynkoop Brewing Company  Denver, CO
# 1808                Rail Yard Ale  Wynkoop Brewing Company  Denver, CO
# 1714                    Belgorado  Wynkoop Brewing Company  Denver, CO
# 1149            Worthy IPA (2013)   Worthy Brewing Company    Bend, OR
#
#                          Style    Size    ABV            IBUs
# 1600               Pumpkin Ale  12 oz.  5.50%  Does not apply
# 1978               Schwarzbier  12 oz.  5.50%  Does not apply
# 1308                Chile Beer  12 oz.  4.20%  Does not apply
# 1336       American Strong Ale  12 oz.  8.20%  Does not apply
# 2332  American Amber / Red Ale  12 oz.  5.20%  Does not apply
# 1610            American Stout  12 oz.  7.50%  Does not apply
# 2286   American Pale Ale (APA)  12 oz.  5.50%              40
# 1808  American Amber / Red Ale  12 oz.  5.20%  Does not apply
# 1714               Belgian IPA  12 oz.  6.70%              45
# 1149              American IPA  12 oz.  6.90%              69

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df.sort_values(by="ABV")
# Out:
#                                                    Beer  \
# 1992                                        Scotty K NA
# 115                                              4Beans
# 125    Lee Hill Series Vol. 4 - Manhattan Style Rye Ale
# 68                                                 Csar
# 7                                        London Balling
# 124   Lee Hill Series Vol. 5 - Belgian Style Quadrup...
# 1366                                        Bikini Beer
# 207                                      Totally Radler
# 381                                         Summer Brew
# 455                                      American Light
# 2039                                        Rocket Girl
# 421                                                 Rad
# 1240                                Weiss Trash Culture
# 1832                       Carolina Blonde Light (2005)
# 1921                                   Drop Dead Blonde
# 144                               Passion Fruit Prussia
# 653                                       Montauk Light
# 1022                                Banner American Ale
# 109                                                Gose
# 343                                       Gansett Light
# 1415                          Pit Stop Chocolate Porter
# 1598                    Back in the Saddle Rye Pale Ale
# 1416                      Pace Setter Belgian Style Wit
# 573                                           Even Keel
# 644                                             Pub Ale
# 1082                                 Wolfman's Berliner
# 2194                                Sankaty Light Lager
# 2081                Maibock / Helles Bock    16 oz.     NaN  Does not apply
# 2118  Extra Special / Strong Bitter (ESB)    16 oz.     NaN  Does not apply
# 2119       American Double / Imperial IPA    16 oz.     NaN  Does not apply
# 2120              American Pale Ale (APA)    16 oz.     NaN  Does not apply
# 2121                      Irish Dry Stout    16 oz.     NaN  Does not apply
# 2122                English Dark Mild Ale    16 oz.     NaN  Does not apply
# 2160                                  NaN       NaN     NaN             NaN
# 2189                         Scottish Ale    12 oz.     NaN  Does not apply
# 2216                         American IPA    12 oz.     NaN  Does not apply
# 2226                                  NaN       NaN     NaN             NaN
# 2238                 Märzen / Oktoberfest    12 oz.     NaN  Does not apply
# 2243              American Pale Ale (APA)    16 oz.     NaN  Does not apply
# 2247                  American Blonde Ale    12 oz.     NaN  Does not apply
# 2276                                  NaN       NaN     NaN             NaN
# 2288                         American IPA    12 oz.     NaN  Does not apply
# 2303              American Dark Wheat Ale    12 oz.     NaN  Does not apply
# 2352             American Amber / Red Ale    12 oz.     NaN  Does not apply
# 2355                  American Pale Lager    12 oz.     NaN  Does not apply
# 2356                   American Brown Ale    12 oz.     NaN  Does not apply
# 2357                   American Brown Ale    12 oz.     NaN  Does not apply
# 2358                  American Blonde Ale    12 oz.     NaN  Does not apply
# 2359             American Amber / Red Ale    12 oz.     NaN  Does not apply
# 2374                                  NaN       NaN     NaN             NaN
# 2376                                  NaN       NaN     NaN             NaN
#
# [2416 rows x 7 columns]

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take a few steps!
#
# ### First, let's just look at the ABV column by itself

# %%
df.ABV
# Out:
# 0        4.50%
# 1        4.90%
# 2        4.80%
# 3        6.00%
# 4        6.00%
# 5        5.60%
# 6        8.00%
# 7       12.50%
# 8        7.70%
# 9        4.20%
# 10       5.00%
# 11       6.60%
# 12       4.00%
# 13       5.50%
# 14       7.60%
# 15       5.10%
# 16       6.50%
# 17       6.00%
# 18       5.00%
# 19       5.20%
# 20       4.80%
# 21       7.20%
# 22       6.70%
# 23       4.90%
# 24       8.00%
# 25       7.50%
# 26       6.00%
# 27       8.00%
# 28       6.30%
# 29       5.80%
#          ...
# 2386     5.70%
# 2387     6.20%
# 2388     4.90%
# 2389     9.90%
# 2390     6.20%
# 2391     5.80%
# 2392     5.20%
# 2393     8.50%
# 2394     7.00%
# 2395     5.30%
# 2396     5.60%
# 2397     4.90%
# 2398     5.10%
# 2399     4.00%
# 2400     5.50%
# 2401     5.10%
# 2402     5.10%
# 2403     9.70%
# 2404     5.10%
# 2405     6.70%
# 2406     6.20%
# 2407     8.30%
# 2408     7.00%
# 2409     4.90%
# 2410     9.90%
# 2411     5.30%
# 2412     9.90%
# 2413     8.00%
# 2414     8.70%
# 2415     6.50%
# Name: ABV, Length: 2416, dtype: object

# %% [markdown]
# ### Hm, `%` isn't part of  a number. Let's remove it.
#
# When you're confident you got it right, save the results back into the `ABV` column.
#
# - *Tip: In programming the easiest way to remove something is to *replacing it with nothing*.
# - *Tip: "nothing" might seem like `NaN` sinc we talked about it a lot in class, but in this case it isn't! It's just an empty string, like ""*
# 2399  Brooklyn Center, MN                       English Bitter  16 oz.   4.00
# 2400  Brooklyn Center, MN                             Rye Beer  16 oz.   5.50
# 2401  Brooklyn Center, MN                   American Brown Ale  16 oz.   5.10
# 2402  Brooklyn Center, MN                   American Brown Ale  16 oz.   5.10
# 2403  Brooklyn Center, MN       American Double / Imperial IPA  16 oz.   9.70
# 2404  Brooklyn Center, MN           Keller Bier / Zwickel Bier  16 oz.   5.10
# 2405  Brooklyn Center, MN               Saison / Farmhouse Ale  16 oz.   6.70
# 2406  Brooklyn Center, MN                         American IPA  16 oz.   6.20
# 2407    San Francisco, CA                     Belgian Dark Ale  12 oz.   8.30
# 2408    San Francisco, CA                         American IPA  12 oz.   7.00
# 2409    San Francisco, CA               Fruit / Vegetable Beer  12 oz.   4.90
# 2410         Longmont, CO               Russian Imperial Stout  12 oz.   9.90
# 2411         Longmont, CO                       Czech Pilsener  12 oz.   5.30
# 2412         Longmont, CO       American Double / Imperial IPA  12 oz.   9.90
# 2413         Longmont, CO                         Scottish Ale  12 oz.   8.00
# 2414         Longmont, CO       American Double / Imperial IPA  12 oz.   8.70
# 2415         Longmont, CO              American Pale Ale (APA)  12 oz.   6.50
#
#                 IBUs
# 0                 50
# 1                 26
# 2                 19
# 3                 38
# 4                 25
# 5                 47
# 6                 68
# 7                 80
# 8                 25
# 9                 42
# 10                25
# 11                21
# 12                13
# 13                17
# 14                68
# 15                38
# 16    Does not apply
# 17                65
# 18                20
# 19                18
# 20                15
# 21                80
# 22                65
# 23                45
# 24               100
# 25                85
# 26                24
# 27               100
# 28                30
# 29                28
# ...              ...
# 2386              30
# 2387              65
# 2388  Does not apply
# 2389  Does not apply
# 2390              42
# 2391              35
# 2392              40
# 2393  Does not apply
# 2394             113
# 2395              21
# 2396              11
# 2397              44
# 2398              40
# 2399              37
# 2400              34
# 2401              45
# 2402              45
# 2403             120
# 2404              20
# 2405              33
# 2406              99
# 2407              35
# 2408              65
# 2409              17
# 2410              98
# 2411              35
# 2412             100
# 2413              35
# 2414              85
# 2415              65
#
# [2416 rows x 7 columns]

# %% [markdown]
# ### Now let's turn `ABV` into a numeric data type
#
# Save the results back into the `ABV` column (again), and then check `df.dtypes` to make sure it worked.
#
# - *Tip: We used `.astype(int)` during class, but this has a decimal in it...*

# %%
df['ABV'] = df.ABV.astype(float)
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs         object
# dtype: object

# %% [markdown]
# ## What's the ABV of the average beer look like?
#
# ### Show me in two different ways: one command to show the `median`/`mean`/etc, and secondly show me a chart

# %%
df.ABV.describe()
# Out:
# count    2348.000000
# mean        5.977342
# std         1.354173
# min         0.100000
# 25%         5.000000
# 50%         5.600000
# 75%         6.700000
# max        12.800000
# Name: ABV, dtype: float64

# %%
df.ABV.hist()

# %% [markdown]
# ### We don't have ABV for all of the beers, how many are we missing them from?
#
# - *Tip: You can use `isnull()` or `notnull()` to see where a column is missing data.*
# - *Tip: You just want to count how many `True`s and `False`s there are.*
# - *Tip: It's a weird trick involving something we usually use to count things in a column*

# %%
# 199              12 oz.  NaN  Does not apply
# 200              12 oz.  NaN  Does not apply
# 201              12 oz.  NaN  Does not apply
# 202              12 oz.  NaN  Does not apply
# 217              12 oz.  NaN  Does not apply
# 307              16 oz.  NaN  Does not apply
# 308              16 oz.  NaN  Does not apply
# 324              16 oz.  NaN  Does not apply
# 344              12 oz.  NaN  Does not apply
# 346              12 oz.  NaN  Does not apply
# 365              12 oz.  NaN  Does not apply
# 476              16 oz.  NaN  Does not apply
# 727               16 oz  NaN  Does not apply
# 871              32 oz.  NaN  Does not apply
# 877              12 oz.  NaN  Does not apply
# 883              16 oz.  NaN  Does not apply
# 914              16 oz.  NaN  Does not apply
# 916              12 oz.  NaN  Does not apply
# 942              16 oz.  NaN  Does not apply
# 1122             12 oz.  NaN  Does not apply
# 1306  16 oz. Alumi-Tek®  NaN  Does not apply
# 1486             12 oz.  NaN  Does not apply
# 1552             12 oz.  NaN  Does not apply
# 1553             12 oz.  NaN  Does not apply
# 1589             12 oz.  NaN  Does not apply
# 1619             12 oz.  NaN  Does not apply
# 1679             12 oz.  NaN  Does not apply
# 1698             12 oz.  NaN  Does not apply
# 1702             12 oz.  NaN  Does not apply
# ...                 ...  ...             ...
# 1897             16 oz.  NaN  Does not apply
# 1950             12 oz.  NaN  Does not apply
# 2025                NaN  NaN             NaN
# 2063             16 oz.  NaN  Does not apply
# 2066             12 oz.  NaN  Does not apply
# 2079             12 oz.  NaN  Does not apply
# 2081             16 oz.  NaN  Does not apply
# 2118             16 oz.  NaN  Does not apply
# 2119             16 oz.  NaN  Does not apply
# 2120             16 oz.  NaN  Does not apply
# 2121             16 oz.  NaN  Does not apply
# 2122             16 oz.  NaN  Does not apply
# 2160                NaN  NaN             NaN
# 2189             12 oz.  NaN  Does not apply
# 2216             12 oz.  NaN  Does not apply
# 2226                NaN  NaN             NaN
# 2238             12 oz.  NaN  Does not apply
# 2243             16 oz.  NaN  Does not apply
# 2247             12 oz.  NaN  Does not apply
# 2276                NaN  NaN             NaN
# 2288             12 oz.  NaN  Does not apply
# 2303             12 oz.  NaN  Does not apply
# 2352             12 oz.  NaN  Does not apply
# 2355             12 oz.  NaN  Does not apply
# 2356             12 oz.  NaN  Does not apply
# 2357             12 oz.  NaN  Does not apply
# 2358             12 oz.  NaN  Does not apply
# 2359             12 oz.  NaN  Does not apply
# 2374                NaN  NaN             NaN
# 2376                NaN  NaN             NaN
#
# [68 rows x 7 columns]

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df.Location.value_counts().head(10)
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df.Location == 'Brooklyn, NY']
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
#
# 1857           English Pale Mild Ale             12 oz.   4.5  Does not apply
# 1962         American Pale Ale (APA)             12 oz.   5.5  Does not apply
# 1970         American Pale Wheat Ale             16 oz.   5.2              11
# 1971          Saison / Farmhouse Ale             16 oz.   4.9              35
# 1972  American Double / Imperial IPA             12 oz.   9.1             103
# 2027    English India Pale Ale (IPA)             12 oz.   6.8              47
# 2062                  American Stout             16 oz.   6.3              69
# 2074                     Pumpkin Ale             16 oz.   6.0              48
# 2140                 German Pilsener             16 oz.   5.4              42
# 2141                       Cream Ale             16 oz.   5.2              34
# 2142                        Rye Beer             16 oz.   6.3              57
# 2143                    American IPA             16 oz.   6.4              62
# 2219           English Pale Mild Ale             12 oz.   4.5  Does not apply
# 2350      American Amber / Red Lager             16 oz.   5.2  Does not apply
# 2351      American Amber / Red Lager             12 oz.   5.2  Does not apply

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df.Location == 'Brooklyn, NY'].Brewery.value_counts()
# Out:
# Sixpoint Craft Ales    24
# Brooklyn Brewery        6
# Evil Twin Brewing       5
# KelSo Beer Company      3
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df[df.Brewery == 'Sixpoint Craft Ales'].Style.value_counts()
# Out:
# American IPA                      4
# Rye Beer                          2
# Cream Ale                         2
# American Double / Imperial IPA    2
# German Pilsener                   2
# Baltic Porter                     2
# American Pale Ale (APA)           1
# American Strong Ale               1
# Gose                              1
# Fruit / Vegetable Beer            1
# American Pale Wheat Ale           1
# American Brown Ale                1
# Belgian Pale Ale                  1
# American Stout                    1
# Saison / Farmhouse Ale            1
# Pumpkin Ale                       1
# Name: Style, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state.
#
# - *Tip: We want to match *part* of the `Location` column, but not all of it.*
# - *Tip: Watch out for `NaN` values! You might be close, but you'll need to pass an extra parameter to make it work without an error.*

# %%
df.Location.str.contains ("NY", na=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2386    False
# 2387    False
# 2388    False
# 2389    False
# 2390    False
# 2391    False
# 2392    False
# 2393    False
# 2394    False
# 2395    False
# 2396    False
# 2397    False
# 2398    False
# 2399    False
# 2400    False
# 2401    False
# 2402    False
# 2403    False
# 2404    False
# 2405    False
# 2406    False
# 2407    False
# 2408    False
# 2409    False
# 2410    False
# 2411    False
# 2412    False
# 2413    False
# 2414    False
# 2415    False
# Name: Location, Length: 2416, dtype: bool

# %%
df[df.Location.str.contains ("NY", na=False)]
# Out:
#                                   Beer                     Brewery  \
# 115                             4Beans         Sixpoint Craft Ales
# 210                             Jammer         Sixpoint Craft Ales
# 246                            Abigale         Sixpoint Craft Ales
# 404                      Nomader Weiss           Evil Twin Brewing
# 421                                Rad         Sixpoint Craft Ales
# 439                       Molotov Lite           Evil Twin Brewing
# 588                            Bengali         Sixpoint Craft Ales
# 598                           8 Barrel             Chatham Brewing
# 599                        Oktoberfest             Chatham Brewing
# 628                          Cream Ale    Newburgh Brewing Company
# 653                      Montauk Light   Southampton Publick House
# 713                      Sensi Harvest         Sixpoint Craft Ales
# 768                 Montauk Summer Ale     Montauk Brewing Company
# 769                      Driftwood Ale     Montauk Brewing Company
# 837                     Our Legacy IPA        Matt Brewing Company
# 628        Newburgh, NY                            Cream Ale
# 653     Southampton, NY                          Light Lager
# 713        Brooklyn, NY              American Pale Ale (APA)
# 768         Montauk, NY                  American Blonde Ale
# 769         Montauk, NY  Extra Special / Strong Bitter (ESB)
# 837           Utica, NY                         American IPA
# 918           Bronx, NY              American Pale Ale (APA)
# 919           Bronx, NY                   American Black Ale
# 969        Brooklyn, NY       American Double / Imperial IPA
# 987        Brooklyn, NY                      Euro Dark Lager
# 1057       Brooklyn, NY                  American Strong Ale
# 1074       Brooklyn, NY                         American IPA
# 1093       Brooklyn, NY                         American IPA
# 1267       Brooklyn, NY                      German Pilsener
# 1268       Brooklyn, NY                            Cream Ale
# 1269       Brooklyn, NY                             Rye Beer
# 1270       Brooklyn, NY                         American IPA
# 1295          Utica, NY                               Shandy
# 1305       Brooklyn, NY                       Czech Pilsener
# 1365       Brooklyn, NY              American Pale Ale (APA)
# 1366       Brooklyn, NY                         American IPA
# ...                 ...                                  ...
# 1913      Patchogue, NY                   American White IPA
# 1919          Utica, NY                         American IPA
# 1935      Patchogue, NY                  American Blonde Ale
# 1937      Patchogue, NY                         Vienna Lager
# 1962       Brooklyn, NY              American Pale Ale (APA)
# 1970       Brooklyn, NY              American Pale Wheat Ale
# 1971       Brooklyn, NY               Saison / Farmhouse Ale
# 1972       Brooklyn, NY       American Double / Imperial IPA
# 2015       New York, NY                  Munich Helles Lager
# 2027       Brooklyn, NY         English India Pale Ale (IPA)
# 2062       Brooklyn, NY                       American Stout
# 2073       New York, NY                  Munich Helles Lager
# 2074       Brooklyn, NY                          Pumpkin Ale
# 2113      Rochester, NY              American Pale Wheat Ale
# 2116          Utica, NY              American Pale Wheat Ale
# 2140       Brooklyn, NY                      German Pilsener
# 2141       Brooklyn, NY                            Cream Ale
# 2142       Brooklyn, NY                             Rye Beer
# 2143       Brooklyn, NY                         American IPA
# 2180         Elmira, NY                   American Brown Ale
# 2181         Elmira, NY                         American IPA
# 2219       Brooklyn, NY                English Pale Mild Ale
# 2282          Utica, NY                     English Pale Ale
# 2293          Utica, NY                     English Pale Ale
# 2350       Brooklyn, NY           American Amber / Red Lager
# 2351       Brooklyn, NY           American Amber / Red Lager
# 2364  Garrattsville, NY                           Hefeweizen
# 2365  Garrattsville, NY                         American IPA
# 2366  Garrattsville, NY                   Milk / Sweet Stout
# 2367  Garrattsville, NY              American Pale Ale (APA)
#
#                    Size   ABV            IBUs
# 115              12 oz.  10.0              52
# 210     12 oz. Slimline   4.2              16
# 246              12 oz.   8.0  Does not apply
# 404              12 oz.   4.0  Does not apply
# 421              16 oz.   3.2               7
# 439              16 oz.   8.5  Does not apply
# 588   24 oz. "Silo Can"   6.5              62
# 598              16 oz.   8.0              69
# 599              16 oz.   5.5              40
# 628              12 oz.   4.2              35
# 653              12 oz.   3.5  Does not apply
# 713              12 oz.   4.7              50
# 768              12 oz.   5.6              28
# 769              12 oz.   6.0              49
# 837              12 oz.   6.5              60
# 918              16 oz.   5.2              16
# 919              16 oz.   5.7              46
# 969              12 oz.   9.9             111
# 987              12 oz.   5.7              19
# 1057             12 oz.   7.0              70
# 1074             16 oz.   6.7              74
# 1093             12 oz.   6.0              64
# 1267             16 oz.   5.4              42
# 1268             16 oz.   5.2              34
# 1269             16 oz.   6.3              57
# 1270             16 oz.   6.4              62
# 1295             12 oz.   4.2  Does not apply
# 1305             12 oz.   5.5              23
# 1365             12 oz.   5.5  Does not apply
# 1366             12 oz.   2.7  Does not apply
# ...                 ...   ...             ...
# 1913             12 oz.   6.0              40
# 1919             12 oz.   6.0  Does not apply
# 1935             12 oz.   4.4              16
# 1937             12 oz.   5.5              28
# 1962             12 oz.   5.5  Does not apply
# 1970             16 oz.   5.2              11
# 1971             16 oz.   4.9              35
# 1972             12 oz.   9.1             103
# 2015             12 oz.   5.1  Does not apply
# 2027             12 oz.   6.8              47
# 2062             16 oz.   6.3              69
# 2073             12 oz.   4.5              27
# 2074             16 oz.   6.0              48
# 2113             12 oz.   4.5              18
# 2116             12 oz.   4.7  Does not apply
# 2140             16 oz.   5.4              42
# 2141             16 oz.   5.2              34
# 2142             16 oz.   6.3              57
# 2143             16 oz.   6.4              62
# 2180             16 oz.   5.3              22
# 2181             12 oz.   6.5              70
# 2219             12 oz.   4.5  Does not apply
# 2282             12 oz.   5.5  Does not apply
# 2293             16 oz.   5.5  Does not apply
# 2350             16 oz.   5.2  Does not apply
# 2351             12 oz.   5.2  Does not apply
# 2364             12 oz.   4.9  Does not apply
# 2365             12 oz.   6.8  Does not apply
# 2366             12 oz.   4.9  Does not apply
# 2367             12 oz.   4.3  Does not apply
#
# [74 rows x 7 columns]

# %% [markdown]
# ### Now *count* all of the breweries in New York state

# %%
len(df[df.Location.str.contains ("NY", na=False)])
# Out:
# 74

# %% [markdown]
# # Measuring International Bitterness Units
#
# ## Display all of the IPAs
#
# Include American IPAs, Imperial IPAs, and anything else with "IPA in it."
#
# IPA stands for [India Pale Ale](https://www.bonappetit.com/story/ipa-beer-styles), and is probably the most popular kind of beer in the US for people who are drinking [craft beer](https://www.craftbeer.com/beer/what-is-craft-beer).

# %%
df.IBUs
# Out:
# 0                   50
# 1                   26
# 2                   19
# 3                   38
# 4                   25
# 5                   47
# 6                   68
# 7                   80
# 8                   25
# 9                   42
# 10                  25
# 11                  21
# 12                  13
# 13                  17
# 14                  68
# 15                  38
# 16      Does not apply
# 17                  65
# 18                  20
# 19                  18
# 20                  15
# 21                  80
# 22                  65
# 23                  45
# 24                 100
# 25                  85
# 26                  24
# 27                 100
# 28                  30
# 29                  28
#              ...
# 2386                30
# 2387                65
# 2388    Does not apply
# 2389    Does not apply
# 2390                42
# 2391                35
# 2392                40
# 2393    Does not apply
# 2394               113
# 2395                21
# 2396                11
# 2397                44
# 2398                40
# 2399                37
# 2400                34
# 2401                45
# 2402                45
# 2403               120
# 2404                20
# 2405                33
# 2406                99
# 2407                35
# 2408                65
# 2409                17
# 2410                98
# 2411                35
# 2412               100
# 2413                35
# 2414                85
# 2415                65
# Name: IBUs, Length: 2416, dtype: object

# %% [markdown]
# IPAs are usually pretty hoppy and bitter. IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## Try to get the average IBU measurement across all beers

# %%
df.IBUs.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna)
#     379     if not is_float_dtype(values):
# --> 380         values = values.astype('f8')
#     381         values[mask] = np.nan
#
# ValueError: could not convert string to float: 'Does not apply'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna)
#     379     if not is_float_dtype(values):
# --> 380         values = values.astype('f8')
#     381         values[mask] = np.nan
#
# ValueError: could not convert string to float: 'Does not apply'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-3ddc1a4b2df7> in <module>()
# ----> 1 df.IBUs.median()
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    9587                                       skipna=skipna)
#    9588         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9589                             numeric_only=numeric_only)
#    9590
#    9591     return set_function_name(stat_func, name, cls)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3216                                           'numeric_only.'.format(name))
#    3217             with np.errstate(all='ignore'):
# -> 3218                 return op(delegate, skipna=skipna, **kwds)
#    3219
#    3220         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     137
#     138                     if is_object_dtype(values):
# --> 139                         raise TypeError(e)
#     140                     raise
#     141
#
# TypeError: could not convert string to float: 'Does not apply'

# %% [markdown]
# ### Oh no, it doesn't work!
#
# It looks like some of those values *aren't numbers*. There are two ways to fix this:
#
# 1. Do the `.replace` and `np.nan` thing we did in class. Then convert the column to a number. This is boring.
# 2. When you're reading in your csv, there [is an option called `na_values`](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.read_csv.html). You can give it a list of **numbers or strings to count as `NaN`**. It's a lot easier than doing the `np.nan` thing, although you'll need to go add it up top and run all of your cells again.
#
# - *Tip: Make sure you're giving `na_values` a LIST, not just a string*
#
# ### Now try to get the average IBUs again

# %%
import numpy as np
df.IBUs.replace("Does not apply", np.nan, inplace=True)

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *twenty* bins instead of the default of 10
#
# - *Tip: Every time I ask for a distribution, I'm looking for a histogram*
# - *Tip: Use the `?` to get all of the options for building a histogram*
# - *Tip: Make sure your `matplotlib` thing is set up right!*

# %% [markdown]
# ## Hm, Interesting distribution. List all of the beers with IBUs above the 75th percentile
#
# - *Tip: There's a single that gives you the 25/50/75th percentile*
# - *Tip: You can just manually type the number when you list those beers*

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the missing ones at the bottom.
#
# - Tip: Look at the options for `sort_values` to figure out the `NaN` thing. The `?` probably won't help you here.

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# - *Tip: You'll want to think about it in three pieces - filtering to only find the specific beers beers, then finding out what the most common styles are, then getting the top 5.*
# - *Tip: You CANNOT do this in one command. It's going to be one command for the high and one for the low.*
# - *Tip: "High IBU" means higher than 75th percentile, "Low IBU" is under 25th percentile*

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles
#
# I'm counting these as wheat beers. If you see any other wheat beer categories, feel free to include them. I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.
#
# - *Tip: I hope that `isin` is in your toolbox*

# %% [markdown]
# ## Draw a histogram of the IBUs of those beers

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %% [markdown]
# ## Plot those two histograms on top of one another
#
# To plot two plots on top of one another, you do two steps.
#
# 1. First, you make a plot using `plot` or `hist`, and you save it into a variable called `ax`.
# 2. You draw your second graph using `plot` or `hist`, and send `ax=ax` to it as a parameter.
#
# It would look something like this:
#
# ```python
# ax = df.plot(....)
# df.plot(ax=ax, ....)
# ```
#
# (...except totally different)

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs : their IBUs were really different, but how about their alcohol percentage?
#
# Wheat beers might include witbier, hefeweizen, American Pale Wheat Ale, and anything else you think is wheaty. IPAs probably have "IPA" in their name.

# %% [markdown]
# ## Good work!
#
# If you made it this far you deserve a drink.
